# %%
Hardware refers to the physical parts of a computer that we can touch, like keyboard and monitor. Software refers to programs and applications that run on a computer, like Windows or Google Chrome.

Example: Keyboard is hardware, MS Word is software.
